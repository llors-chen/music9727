# %% [markdown]
# # Introduction

# %% [markdown]
# The digital age is rapidly developing today, and music streaming has become a part of daily life, providing users with instant access to a vast library of music from various genres and styles. Music recommendations continue to receive a lot of attention in the task of recommending multimedia products. Spotify, the leading music streaming service, utilizes an advanced recommendation system to enhance the user experience by providing personalized music suggestions. This project aims to curate a unique musical journey for each user, driven by sophisticated algorithms that analyze user behavior and preferences.

# %% [markdown]
# # Problem Statement

# %% [markdown]
# Although music recommendation systems have made significant progress in personalized recommendations, there are still some urgent problems to be solved. The cold start dilemma caused by insufficient data for new users and new music has long been a tough problem plaguing the industry. Recommendation results often fall into an "echo chamber" effect, where users easily get trapped in their own music comfort zones, missing out on potential music treasures. Popular songs tend to be favored, while those niche but unique music pieces are often overlooked, this long-tail effect limiting the breadth of users' exploration of the music world.
#
# Moreover, complex algorithms and real-time processing requirements pose huge challenges to computational resources, especially on mobile devices. Users' music tastes also change like the seasons; today they might be obsessed with rock, tomorrow they might be immersed in the world of classical music. Recommendation systems need to keenly capture these changes.

# %% [markdown]
# # Metric

# %% [markdown]
# In this project, we aim for our recommendation algorithm to provide precise recommendations, capturing user preferences without recommending excessive or redundant information. Therefore, we use **precision**, which measures the proportion of recommended songs that the user likes out of all recommended songs, and **recall**, which measures the proportion of recommended songs that the user likes out of all songs the user actually likes. We then combine precision and recall into the **F1-score** as the final evaluation metric. The F1-score balances precision and recall, allowing for a better assessment of the trade-off between recommendation coverage and accuracy. This approach limits the system from expanding the recommendation scope excessively to cover items the user might like, or sacrificing recommendation diversity for accuracy.

# %% [markdown]
# # Load data

# %%
import pandas as pd

# %%
user_raw = pd.read_csv('../dataset/spotify_dataset.csv',on_bad_lines='skip')
song_raw = pd.read_csv('../dataset/spotify_millsongdata.csv')
user_raw.columns = user_raw.columns.str.replace('"', '').str.strip()
song_raw = song_raw.drop('link', axis=1)

# %%
song_raw
# Out:
#              artist                   song  \
# 0              ABBA  Ahe's My Kind Of Girl
# 1              ABBA       Andante, Andante
# 2              ABBA         As Good As New
# 3              ABBA                   Bang
# 4              ABBA       Bang-A-Boomerang
# ...             ...                    ...
# 57645  Ziggy Marley          Good Old Days
# 57646  Ziggy Marley          Hand To Mouth
# 57647          Zwan           Come With Me
# 57648          Zwan                 Desire
# 57649          Zwan              Heartsong
#
#                                                     text
# 0      Look at her face, it's a wonderful face  \r\nA...
# 1      Take it easy with me, please  \r\nTouch me gen...
# 2      I'll never know why I had to go  \r\nWhy I had...
# 3      Making somebody happy is a question of give an...
# 4      Making somebody happy is a question of give an...
# ...                                                  ...
# 57645  Irie days come on play  \r\nLet the angels fly...
# 57646  Power to the workers  \r\nMore power  \r\nPowe...
# 57647  all you need  \r\nis something i'll believe  \...
# 57648  northern star  \r\nam i frightened  \r\nwhere ...
# 57649  come in  \r\nmake yourself at home  \r\ni'm a ...
#
# [57650 rows x 3 columns]

# %%
user_raw
# Out:
#                                    user_id                        artistname  \
# 0         9cc0cfd4d7d7885102480dd99e7a90d6                    Elvis Costello
# 1         9cc0cfd4d7d7885102480dd99e7a90d6  Elvis Costello & The Attractions
# 2         9cc0cfd4d7d7885102480dd99e7a90d6                      Tiffany Page
# 3         9cc0cfd4d7d7885102480dd99e7a90d6  Elvis Costello & The Attractions
# 4         9cc0cfd4d7d7885102480dd99e7a90d6                    Elvis Costello
# ...                                    ...                               ...
# 12891675  2302bf9c64dc63d88a750215ed187f2c                       Mötley Crüe
# 12891676  2302bf9c64dc63d88a750215ed187f2c                       John Lennon
# 12891677  2302bf9c64dc63d88a750215ed187f2c                         Tom Petty
# 12891678  2302bf9c64dc63d88a750215ed187f2c                         Tom Petty
# 12891679  2302bf9c64dc63d88a750215ed187f2c                          Skid Row
#
#                                                   trackname    playlistname
# 0                      (The Angels Wanna Wear My) Red Shoes  HARD ROCK 2010
# 1         (What's So Funny 'Bout) Peace, Love And Unders...  HARD ROCK 2010
# 2                                          7 Years Too Late  HARD ROCK 2010
# 3                                     Accidents Will Happen  HARD ROCK 2010
# 4                                                    Alison  HARD ROCK 2010
# ...                                                     ...             ...
# 12891675                                          Wild Side          iPhone
# 12891676                                              Woman          iPhone
# 12891677                        You Don't Know How It Feels          iPhone
# 12891678                                       You Wreck Me          iPhone
# 12891679                                    Youth Gone Wild          iPhone
#
# [12891680 rows x 4 columns]

# %%
merge_df = pd.merge(user_raw, song_raw, how='left', left_on=['trackname', 'artistname'], right_on=['song', 'artist'])
merge_df = merge_df.dropna()
merge_df = merge_df.drop_duplicates()
merge_df.reset_index(drop=True, inplace=True)
merge_df = merge_df.drop(columns=['artist', 'song','text'])
merge_df
# Out:
#                                  user_id           artistname  \
# 0       9cc0cfd4d7d7885102480dd99e7a90d6       Elvis Costello
# 1       9cc0cfd4d7d7885102480dd99e7a90d6       Paul McCartney
# 2       9cc0cfd4d7d7885102480dd99e7a90d6       Paul McCartney
# 3       9cc0cfd4d7d7885102480dd99e7a90d6        Crowded House
# 4       9cc0cfd4d7d7885102480dd99e7a90d6        Crowded House
# ...                                  ...                  ...
# 980823  2302bf9c64dc63d88a750215ed187f2c          Soundgarden
# 980824  2302bf9c64dc63d88a750215ed187f2c          Def Leppard
# 980825  2302bf9c64dc63d88a750215ed187f2c         Jimi Hendrix
# 980826  2302bf9c64dc63d88a750215ed187f2c            Metallica
# 980827  2302bf9c64dc63d88a750215ed187f2c  Stone Temple Pilots
#
#                            trackname    playlistname
# 0                             Alison  HARD ROCK 2010
# 1                    Band On The Run  HARD ROCK 2010
# 2                      Dance Tonight  HARD ROCK 2010
# 3              Don't Dream It's Over  HARD ROCK 2010
# 4                  Fall At Your Feet  HARD ROCK 2010
# ...                              ...             ...
# 980823       The Day I Tried To Live          iPhone
# 980824             Too Late For Love          iPhone
# 980825  Voodoo Child (Slight Return)          iPhone
# 980826     Welcome Home (Sanitarium)          iPhone
# 980827                 Wicked Garden          iPhone
#
# [980828 rows x 4 columns]

# %% [markdown]
# Merge the song library data with the user interaction data using the song name and artist, filtering out unusable information, such as songs favorited by users that don't exist in the song library. This is in preparation for the development of recommendation algorithms.

# %% [markdown]
# # Data preprocessing

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Preprocessing method

# %%
import re
import nltk
from nltk.corpus import stopwords, wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
nltk.download('stopwords')
nltk.download('punkt')

ps = PorterStemmer()
stop_words = set(stopwords.words('english'))
def preprocess_text(text):
    text = re.sub(r'\r\n', ' ', text)
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word not in stop_words]
    tokens = [ps.stem(word) for word in tokens]
    return ' '.join(tokens)

def preprocess_combined(row):
    artist = preprocess_text(row['artist'])
    song = preprocess_text(row['song'])
    text = preprocess_text(row['text'])
    return f"{artist} {song} {text}"
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\11580\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\11580\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# The above is our method for text processing. We first remove carriage returns and line breaks from the text, then retain only expression symbols that convey word meanings, such as hyphens. Additionally, because subsequent development does not involve semantic and lexical analysis, we also convert the text to lowercase and remove stopwords to reduce interference with important information. Finally, we reduce the morphological variation of words by restoring them to their basic forms. By using the aforementioned methods to preprocess and tokenize the textual data in our dataset (text/lyrics, artist name, track name), we enhance the accuracy of the user profiles we build subsequently.

# %%
song_raw['text1'] = song_raw.apply(preprocess_combined, axis=1)

# %% [markdown]
# ## Split dataset into training set and test set

# %%
from sklearn.model_selection import train_test_split
from tqdm import tqdm

train_df = pd.DataFrame()
test_df = pd.DataFrame()

user_groups = merge_df.groupby(['user_id','playlistname'])
total_groups = len(user_groups)

for user_id, user_data in tqdm(user_groups, total=total_groups, desc="Processing users"):
    if len(user_data) > 1:
        train_data, test_data = train_test_split(user_data, test_size=0.2, random_state=42)
        train_df = pd.concat([train_df, train_data])
        test_df = pd.concat([test_df, test_data])
# Out:
# Processing users: 100%|██████████| 81450/81450 [26:51<00:00, 50.53it/s]

# %% [markdown]
# Considering the diversity and representativeness of playlists created by users, we need to give equal weight to each playlist when building user profiles. This approach can somewhat eliminate these differences and create more comprehensive and accurate user profiles. For instance, if the data used to build user profiles comes from the same playlist, the recommendation algorithm would only suggest similar items, ignoring the diversity of user preferences. Therefore, we use playlists as the smallest unit of our dataset to divide into training and testing sets.

# %%
train_df = pd.merge(train_df, song_raw, how='left', left_on=['trackname', 'artistname'], right_on=['song', 'artist'])
train_df = train_df.dropna()
train_df = train_df.drop_duplicates()
train_df.reset_index(drop=True, inplace=True)
train_df
# Out:
#                                  user_id       artistname  \
# 0       00055176fea33f6e027cd3302289378b       Little Mix
# 1       00055176fea33f6e027cd3302289378b      Demi Lovato
# 2       00055176fea33f6e027cd3302289378b  Imagine Dragons
# 3       00055176fea33f6e027cd3302289378b       Bruno Mars
# 4       00055176fea33f6e027cd3302289378b    One Direction
# ...                                  ...              ...
# 744741  fff77dadf8528083c920b9c018847e8b     Fall Out Boy
# 744742  fff77dadf8528083c920b9c018847e8b     Lana Del Rey
# 744743  fff77dadf8528083c920b9c018847e8b     Lana Del Rey
# 744744  fff77dadf8528083c920b9c018847e8b     Mariah Carey
# 744745  fff77dadf8528083c920b9c018847e8b      The Killers
#
#                                                 trackname      playlistname  \
# 0                                               Little Me              favs
# 1                                         Made In The USA              favs
# 2                                           I Bet My Life              favs
# 3                                                Treasure              favs
# 4                                              Act My Age              favs
# ...                                                   ...               ...
# 744741  I've Got All This Ringing In My Ears And None ...  Liked from Radio
# 744742                                             Lolita  Liked from Radio
# 744743                                               Cola  Liked from Radio
# 744744                                               Hero  Liked from Radio
# 744745                                           Runaways  Liked from Radio
#
#                  artist                                               song  \
# 0            Little Mix                                          Little Me
# 1           Demi Lovato                                    Made In The USA
# 2       Imagine Dragons                                      I Bet My Life
# 3            Bruno Mars                                           Treasure
# 4         One Direction                                         Act My Age
# ...                 ...                                                ...
# 744741     Fall Out Boy  I've Got All This Ringing In My Ears And None ...
# 744742     Lana Del Rey                                             Lolita
# 744743     Lana Del Rey                                               Cola
# 744744     Mariah Carey                                               Hero
# 744745      The Killers                                           Runaways
#
#                                                      text  \
# 0       She lives in the shadow of a lonely girl  \r\n...
# 1       Our love runs deep like a chevy  \r\nIf you fa...
# 2       [Verse]  \r\nI knew I took the path  \r\nThat ...
# 3       Give me all, give me all, give me all your att...
# 4       [Verse 1: Niall]  \r\nWhen I'm fat and old  \r...
# ...                                                   ...
# 744741  You're a canary  \r\nI'm a coal mine  \r\n'Cau...
# 744742  Would you be mine?  \r\nWould you be my baby t...
# 744743  My pussy tastes like Pepsi Cola  \r\nMy eyes a...
# 744744  There's a hero  \r\nIf you look inside your he...
# 744745  Blonde hair blowin' in the summer wind  \r\nA ...
#
#                                                     text1
# 0       littl mix littl live shadow lone girl voic qui...
# 1       demi lovato made usa love run deep like chevi ...
# 2       imagin dragon bet life vers knew took path wou...
# 3       bruno mar treasur give give give attent babi g...
# 4       one direct act age vers niall im fat old kid t...
# ...                                                   ...
# 744741  fall boy ive got ring ear none finger your can...
# 744742  lana del rey lolita would mine would babi toni...
# 744743  lana del rey cola pussi tast like pepsi cola e...
# 744744  mariah carey hero there hero look insid heart ...
# 744745  killer runaway blond hair blowin summer wind b...
#
# [744746 rows x 8 columns]

# %%
test_df = pd.merge(test_df, song_raw, how='left', left_on=['trackname', 'artistname'], right_on=['song', 'artist'])
test_df = test_df.dropna()
test_df = test_df.drop_duplicates()
test_df.reset_index(drop=True, inplace=True)
test_df
# Out:
#                                  user_id         artistname  \
# 0       00055176fea33f6e027cd3302289378b         Ed Sheeran
# 1       00055176fea33f6e027cd3302289378b        OneRepublic
# 2       00055176fea33f6e027cd3302289378b      Avril Lavigne
# 3       00055176fea33f6e027cd3302289378b         Little Mix
# 4       00055176fea33f6e027cd3302289378b          Green Day
# ...                                  ...                ...
# 219459  fff77dadf8528083c920b9c018847e8b             Travis
# 219460  fff77dadf8528083c920b9c018847e8b       Fall Out Boy
# 219461  fff77dadf8528083c920b9c018847e8b  Justin Timberlake
# 219462  fff77dadf8528083c920b9c018847e8b     Britney Spears
# 219463  fff77dadf8528083c920b9c018847e8b        The Killers
#
#                        trackname      playlistname             artist  \
# 0                        Friends              favs         Ed Sheeran
# 1                        I Lived              favs        OneRepublic
# 2                     Girlfriend              favs      Avril Lavigne
# 3       They Just Don't Know You              favs         Little Mix
# 4                        21 Guns              favs          Green Day
# ...                          ...               ...                ...
# 219459                      Sing  Liked from Radio             Travis
# 219460      What A Catch, Donnie  Liked from Radio       Fall Out Boy
# 219461                   My Love  Liked from Radio  Justin Timberlake
# 219462                    Circus  Liked from Radio     Britney Spears
# 219463              Read My Mind  Liked from Radio        The Killers
#
#                             song  \
# 0                        Friends
# 1                        I Lived
# 2                     Girlfriend
# 3       They Just Don't Know You
# 4                        21 Guns
# ...                          ...
# 219459                      Sing
# 219460      What A Catch, Donnie
# 219461                   My Love
# 219462                    Circus
# 219463              Read My Mind
#
#                                                      text  \
# 0       We're not, no we're not friends, nor have we e...
# 1       Hoping you take that jump  \r\nBut don't fear ...
# 2       [Chorus]  \r\nHey, hey  \r\nYou, you  \r\nI do...
# 3       (JADE)  \r\nDaddy doesn't think  \r\nThat you'...
# 4       Do you know what's worth fighting for,  \r\nWh...
# ...                                                   ...
# 219459  Baby, you've been going so crazy  \r\nLately, ...
# 219460  I got troubled thoughts  \r\nAnd the self-este...
# 219461  If I wrote you a symphony  \r\nJust to say how...
# 219462  There's only two types of people in the world ...
# 219463  On the corner of main street  \r\nJust tryin' ...
#
#                                                     text1
# 0       ed sheeran friend friend ever tri keep secret ...
# 1       onerepubl live hope take jump dont fear fall h...
# 2       avril lavign girlfriend choru hey hey dont lik...
# 3       littl mix dont know jade daddi doesnt think yo...
# 4       green day gun know what worth fight worth die ...
# ...                                                   ...
# 219459  travi sing babi youv go crazi late noth seem g...
# 219460  fall boy catch donni got troubl thought selfes...
# 219461  justin timberlak love wrote symphoni say much ...
# 219462  britney spear circu there two type peopl world...
# 219463  killer read mind corner main street tryin keep...
#
# [219464 rows x 8 columns]

# %%
tfidf = TfidfVectorizer(
)
tfidf.fit_transform(song_raw['text1'])
num_features = len(tfidf.vocabulary_)

print(f"Number of features (terms): {num_features}")
# Out:
# Number of features (terms): 73980

# %%
grouped_df = train_df.groupby('user_id').agg({
    'text1': ' '.join
}).reset_index()
grouped_df['index'] = grouped_df.index
grouped_df
# Out:
#                                 user_id  \
# 0      00055176fea33f6e027cd3302289378b
# 1      0007f3dd09c91198371454c608d47f22
# 2      000b0f32b5739f052b9d40fcc5c41079
# 3      000c11a16c89aa4b14b328080f5954ee
# 4      00123e0f544dee3ab006aa7f1e5725a7
# ...                                 ...
# 12807  ffe11226cdea81a2db9262c0ec7f5d71
# 12808  ffe32d5412269f3041c58cbf0dde3306
# 12809  fff60baf392613ed33f745b89a9b38f7
# 12810  fff616055993498d6127f3f467cf9f2b
# 12811  fff77dadf8528083c920b9c018847e8b
#
#                                                    text1  index
# 0      littl mix littl live shadow lone girl voic qui...      0
# 1      evanesc heart broken wander til end time torn ...      1
# 2      mariah carey one child angel appear highest on...      2
# 3      onerepubl count star late ive ive lose sleep d...      3
# 4      neil young everybodi rockin grandma grandpa ge...      4
# ...                                                  ...    ...
# 12807  nightwish storytim night world word dream one ...  12807
# 12808  bruce springsteen true scrapbook fill pictur l...  12808
# 12809  linkin park wasteland war weapon march step mu...  12809
# 12810  jason mraz sleep day moan though cri oh he bui...  12810
# 12811  killer mr brightsid come cage ive fine got ta ...  12811
#
# [12812 rows x 3 columns]

# %% [markdown]
# # Top-N Recommendation Method

# %% [markdown]
# ## Hyperparameter tuning

# %%
import numpy as np
test_user_ids = test_df['user_id'].unique()
test_user_ids = pd.Series(test_user_ids).sample(n=200, random_state=42, replace=False)
test_user_ids = test_user_ids.tolist()

# %% [markdown]
# Due to limitations in computational resources and because our algorithm can make recommendations based on individual users, we want the algorithm to be universally applicable. Therefore, we randomly sampled 200 users as our test set for model evaluation.

# %%
grid = [100,1000,3000,5000,7000,10000,20000,30000,40000,50000]
f1s = []
for g in grid:
    print(g)
    tfidf = TfidfVectorizer(
        max_features = g
    )
    tfidf.fit_transform(song_raw['text1'])
    all_songs = tfidf.transform(song_raw['text1'])
    correct = 0
    total_collect = 0
    total_rcmd = 0
    for id in tqdm(test_user_ids, desc="Processing users"):
        user_collect = train_df[train_df['user_id'] == id]
        user_notcollect = song_raw[~song_raw['text'].isin(user_collect['text'])].copy()
        notcollect_indices = np.where(~song_raw['text'].isin(user_collect['text']))[0]
        profile = tfidf.transform([grouped_df[grouped_df['user_id'] == id]['text1'].values[0]])
        songs = all_songs[notcollect_indices]
        similarity_score = cosine_similarity(songs, profile).flatten()
        user_notcollect['similarity'] = similarity_score
        recommended_songs = user_notcollect.sort_values(by='similarity', ascending=False).head(100)
        user_test = test_df[test_df['user_id'] == id]
        
        recommended_songs['actual'] = recommended_songs.apply(
            lambda row: 1 if row['text'] in user_test['text'].values else 0, axis=1
        )
        correct += recommended_songs['actual'].sum()
        total_rcmd += 100
        total_collect += len(user_test)
    precision = correct / total_rcmd
    recall = correct/ total_collect
    f1_score = 2 * (precision * recall) / (precision + recall) 
    f1s.append(f1_score)
# Out:
# 100
# Processing users: 100%|██████████| 200/200 [00:19<00:00, 10.31it/s]
# 1000
# Processing users: 100%|██████████| 200/200 [00:24<00:00,  8.17it/s]
# 3000
# Processing users: 100%|██████████| 200/200 [00:26<00:00,  7.54it/s]
# 5000
# Processing users: 100%|██████████| 200/200 [00:27<00:00,  7.36it/s]
# 7000
# Processing users: 100%|██████████| 200/200 [00:27<00:00,  7.34it/s]
# 10000
# Processing users: 100%|██████████| 200/200 [00:27<00:00,  7.30it/s]
# 20000
# Processing users: 100%|██████████| 200/200 [00:27<00:00,  7.21it/s]
# 30000
# Processing users: 100%|██████████| 200/200 [00:27<00:00,  7.17it/s]
# 40000
# Processing users: 100%|██████████| 200/200 [00:28<00:00,  7.13it/s]
# 50000
# Processing users: 100%|██████████| 200/200 [00:28<00:00,  7.08it/s]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.plot(grid, f1s, marker='o', linestyle='-', color='b')
plt.xlabel('Max Features')
plt.ylabel('F1 Score')
plt.title('F1 Score vs Max Features in TF-IDF Vectorizer')
plt.grid(True)
plt.show()

# %% [markdown]
# Here, we use the grid search method to explore the impact of different settings of 'max features' in TF-IDF on a basic content-based recommendation algorithm. The diagram above shows the performance of the recommendation algorithm in the test set for each 'max features' setting. As can be seen, when 'max features' is set to 5000, the algorithm has better recommendation capabilities. Therefore, in subsequent development and method optimization, we consistently use the 'max features' setting of 5000 to facilitate comparisons in algorithm design while ensuring a certain level of model performance.

# %% [markdown]
# ## Top-N most similar content base recommender (song vs profile)

# %%
tfidf = TfidfVectorizer(
    max_features = 5000
)
tfidf.fit_transform(song_raw['text1'])
all_songs = tfidf.transform(song_raw['text1'])

# %%
top_N = [100,50,30,20]
correct = [0,0,0,0]
total_rcmd = [0,0,0,0]
total_collect = [0,0,0,0]
for id in tqdm(test_user_ids, desc="Processing users"):
    user_collect = train_df[train_df['user_id'] == id]
    user_notcollect = song_raw[~song_raw['text'].isin(user_collect['text'])].copy()
    notcollect_indices = np.where(~song_raw['text'].isin(user_collect['text']))[0]
    profile = tfidf.transform([grouped_df[grouped_df['user_id'] == id]['text1'].values[0]])
    songs = all_songs[notcollect_indices]
    similarity_score = cosine_similarity(songs, profile).flatten()
    user_notcollect['similarity'] = similarity_score
    recommended_songs = user_notcollect.sort_values(by='similarity', ascending=False)
    user_test = test_df[test_df['user_id'] == id]
    
    recommended_songs['actual'] = recommended_songs.apply(
        lambda row: 1 if row['text'] in user_test['text'].values else 0, axis=1
    )
    for n in range(len(top_N)):
        recommended_songs = recommended_songs.head(top_N[n])
        correct[n] += recommended_songs['actual'].sum()
        total_rcmd[n] += top_N[n]
        total_collect[n] += len(user_test)
# Out:
# Processing users: 100%|██████████| 200/200 [02:58<00:00,  1.12it/s]

# %%
def result_output(top_N,correct,total_rcmd,total_collect):
    top_N = [100, 50, 30, 20]
    precision_list = []
    recall_list = []
    f1_score_list = []
    for n in range(len(top_N)):
        precision = correct[n] / total_rcmd[n] if total_rcmd[n] > 0 else 0
        recall = correct[n] / total_collect[n] if total_collect[n] > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
        
        precision_list.append(precision)
        recall_list.append(recall)
        f1_score_list.append(f1_score)
        
        print(f"\nTop N = {top_N[n]}")
        print(f"Precision (how many songs liked by user in all recommended): {precision}")
        print(f"Recall (how many songs collected by user been recommended): {recall}")
        print(f"F1-Score: {f1_score}")
    plt.figure(figsize=(10, 6))

    plt.plot(top_N, precision_list, marker='o', label='Precision')
    plt.plot(top_N, recall_list, marker='s', label='Recall')
    plt.plot(top_N, f1_score_list, marker='^', label='F1-Score')
    
    plt.xlabel('Top N')
    plt.ylabel('Score')
    plt.title('Precision, Recall, and F1-Score for different Top N')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
result_output(top_N,correct,total_rcmd,total_collect)
# Out:
# Top N = 100
# Precision (how many songs liked by user in all recommended): 0.0016
# Recall (how many songs collected by user been recommended): 0.010110584518167456
# F1-Score: 0.002762788689833801
#
# Top N = 50
# Precision (how many songs liked by user in all recommended): 0.0018
# Recall (how many songs collected by user been recommended): 0.005687203791469194
# F1-Score: 0.002734523357387011
#
# Top N = 30
# Precision (how many songs liked by user in all recommended): 0.0023333333333333335
# Recall (how many songs collected by user been recommended): 0.0044233807266982625
# F1-Score: 0.003055100927441353
#
# Top N = 20
# Precision (how many songs liked by user in all recommended): 0.00325
# Recall (how many songs collected by user been recommended): 0.004107424960505529
# F1-Score: 0.0036287508722958827

# %% [markdown]
# Here, we constructed our first recommendation algorithm using a content-based approach, which builds user profiles based on the information of songs favorited by users in the training set. We then identify songs not favorited by the users in the training set and calculate the similarity of these songs to the user's profile. Based on the similarity ranking, we return the top N songs with the highest similarity. The diagram above shows the performance of the model in the test set for different values of top N. It is evident that the model performs best when returning the top 20 similar songs.

# %% [markdown]
# # Recommend base on similarity distrubution

# %% [markdown]
# Here, we explored the relationship between user profiles and the songs they have favorited. Since the construction of user profiles is based on the combined information of all items favorited by the user, if the songs favorited by a user are mostly similar, the user profile will become more uniform. Consequently, the similarity between the user profile and the data in the training set will generally be higher, because the features in the user profile are more uniform, and a single song may match most of these features. Conversely, if the songs favorited by a user are diverse, the similarity between the user profile and the data in the training set will generally be lower, because the features in the user profile are more varied, and a song may not match all these features.

# %%
tfidf_text1_y = tfidf.transform(grouped_df['text1'])
merged_train = pd.merge(train_df, grouped_df, how='left', left_on=['user_id'], right_on=['user_id'])

# %%
def similarity(row):
    tfidf_text1_x = tfidf.transform([row['text1_x']])
    similarity_score = cosine_similarity(tfidf_text1_x, tfidf_text1_y[int(row['index'])]).flatten()[0]
    return similarity_score
merged_train['similarity'] = merged_train.apply(lambda row: similarity(row), axis=1)

# %%
similarity_threshold = merged_train.groupby('user_id')['similarity'].mean().reset_index()
similarity_sd = merged_train.groupby('user_id')['similarity'].std().reset_index()
grouped_df = pd.merge(grouped_df, similarity_threshold, how='left', left_on=['user_id'], right_on=['user_id'])
grouped_df = pd.merge(grouped_df, similarity_sd, how='left', left_on=['user_id'], right_on=['user_id'])
grouped_df = grouped_df.rename(columns={'similarity_x': 'mean','similarity_y': 'sd'})
grouped_df.to_csv('../dataset/grouped_df.csv', index=False)

# %%
grouped_df = pd.read_csv('../dataset/grouped_df.csv')

# %%
import matplotlib.pyplot as plt


first_user_id = merged_train['user_id'].iloc[10]
first_user_data = merged_train[merged_train['user_id'] == first_user_id]

similarity_scores = first_user_data['similarity']
mean_similarity = similarity_scores.mean()
plt.figure(figsize=(10, 6))
plt.hist(similarity_scores, bins=20, edgecolor='k', alpha=0.7)
plt.axvline(mean_similarity, color='r', linestyle='dashed', linewidth=2, label=f'Mean: {mean_similarity:.4f}')
plt.title(f'Similarity Distribution for User {first_user_id}')
plt.xlabel('Similarity Score')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt


first_user_id = merged_train['user_id'].iloc[100]
first_user_data = merged_train[merged_train['user_id'] == first_user_id]

similarity_scores = first_user_data['similarity']
mean_similarity = similarity_scores.mean()
plt.figure(figsize=(10, 6))
plt.hist(similarity_scores, bins=20, edgecolor='k', alpha=0.7)
plt.axvline(mean_similarity, color='r', linestyle='dashed', linewidth=2, label=f'Mean: {mean_similarity:.4f}')
plt.title(f'Similarity Distribution for User {first_user_id}')
plt.xlabel('Similarity Score')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
similarity_scores = merged_train['similarity']
mean_similarity = similarity_scores.mean()

plt.figure(figsize=(10, 6))
plt.hist(similarity_scores, bins=20, edgecolor='k', alpha=0.7)
plt.axvline(mean_similarity, color='r', linestyle='dashed', linewidth=2, label=f'Mean: {mean_similarity:.4f}')
plt.title('Similarity Distribution for All Users')
plt.xlabel('Similarity Score')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# Additionally, by comparing the similarity between user profiles and the data in the training set and constructing the above similarity distribution graph, it appears that the songs favorited by users follow a normal distribution. Based on the principles of distribution in statistics, we hypothesize that recommending songs that are close to the average similarity will have a higher probability of being liked by users. Consequently, we conducted the following experiment.

# %% [markdown]
# ## Top-N closest to global mean similarity

# %%
similarity_scores = merged_train['similarity']
global_mean_similarity = similarity_scores.mean()
global_mean_similarity
# Out:
# 0.24523641730420473

# %%
top_N = [100,50,30,20]
correct = [0,0,0,0]
total_rcmd = [0,0,0,0]
total_collect = [0,0,0,0]
for id in tqdm(test_user_ids, desc="Processing users"):
    user_collect = train_df[train_df['user_id'] == id]
    user_notcollect = song_raw[~song_raw['text'].isin(user_collect['text'])].copy()
    notcollect_indices = np.where(~song_raw['text'].isin(user_collect['text']))[0]
    profile = tfidf.transform([grouped_df[grouped_df['user_id'] == id]['text1'].values[0]])
    songs = all_songs[notcollect_indices]
    similarity_score = cosine_similarity(songs, profile).flatten()
    user_notcollect['similarity'] = similarity_score
    user_notcollect['dist_to_mean'] = abs(user_notcollect['similarity']-global_mean_similarity)
    recommended_songs = user_notcollect.sort_values(by='dist_to_mean', ascending=True)
    user_test = test_df[test_df['user_id'] == id]
    
    recommended_songs['actual'] = recommended_songs.apply(
        lambda row: 1 if row['text'] in user_test['text'].values else 0, axis=1
    )
    for n in range(len(top_N)):
        recommended_songs = recommended_songs.head(top_N[n])
        correct[n] += recommended_songs['actual'].sum()
        total_rcmd[n] += top_N[n]
        total_collect[n] += len(user_test)
# Out:
# Processing users: 100%|██████████| 200/200 [03:01<00:00,  1.10it/s]

# %%
result_output(top_N,correct,total_rcmd,total_collect)
# Out:
# Top N = 100
# Precision (how many songs liked by user in all recommended): 0.0005
# Recall (how many songs collected by user been recommended): 0.00315955766192733
# F1-Score: 0.0008633714655730629
#
# Top N = 50
# Precision (how many songs liked by user in all recommended): 0.0009
# Recall (how many songs collected by user been recommended): 0.002843601895734597
# F1-Score: 0.0013672616786935055
#
# Top N = 30
# Precision (how many songs liked by user in all recommended): 0.0006666666666666666
# Recall (how many songs collected by user been recommended): 0.001263823064770932
# F1-Score: 0.000872885979268958
#
# Top N = 20
# Precision (how many songs liked by user in all recommended): 0.00075
# Recall (how many songs collected by user been recommended): 0.0009478672985781991
# F1-Score: 0.000837404047452896

# %% [markdown]
# The diagram above illustrates the content-based recommendation algorithm applied after considering the normal distribution. In this modified algorithm, after calculating the similarity, we compute the difference between this similarity and the global average similarity, and then recommend the top N songs that are closest to the global mean based on this difference. From the diagram, it can be seen that although the model performs best when recommending the top 50 songs, its performance is somewhat lacking compared to the original content-based algorithm.

# %% [markdown]
# ## Top-N closest to local(personal) mean similarity

# %%
top_N = [100,50,30,20]
correct = [0,0,0,0]
total_rcmd = [0,0,0,0]
total_collect = [0,0,0,0]
for id in tqdm(test_user_ids, desc="Processing users"):
    user_collect = train_df[train_df['user_id'] == id]
    user_notcollect = song_raw[~song_raw['text'].isin(user_collect['text'])].copy()
    notcollect_indices = np.where(~song_raw['text'].isin(user_collect['text']))[0]
    profile = tfidf.transform([grouped_df[grouped_df['user_id'] == id]['text1'].values[0]])
    songs = all_songs[notcollect_indices]
    similarity_score = cosine_similarity(songs, profile).flatten()
    mean_similarity = grouped_df[grouped_df['user_id'] == id]['mean'].values[0]
    user_notcollect['similarity'] = similarity_score
    user_notcollect['dist_to_mean'] = abs(user_notcollect['similarity']-mean_similarity)
    recommended_songs = user_notcollect.sort_values(by='dist_to_mean', ascending=True)
    user_test = test_df[test_df['user_id'] == id]
    
    recommended_songs['actual'] = recommended_songs.apply(
        lambda row: 1 if row['text'] in user_test['text'].values else 0, axis=1
    )
    for n in range(len(top_N)):
        recommended_songs = recommended_songs.head(top_N[n])
        correct[n] += recommended_songs['actual'].sum()
        total_rcmd[n] += top_N[n]
        total_collect[n] += len(user_test)
# Out:
# Processing users: 100%|██████████| 200/200 [03:01<00:00,  1.10it/s]

# %%
result_output(top_N,correct,total_rcmd,total_collect)
# Out:
# Top N = 100
# Precision (how many songs liked by user in all recommended): 0.0007
# Recall (how many songs collected by user been recommended): 0.0044233807266982625
# F1-Score: 0.0012087200518022879
#
# Top N = 50
# Precision (how many songs liked by user in all recommended): 0.0007
# Recall (how many songs collected by user been recommended): 0.0022116903633491313
# F1-Score: 0.0010634257500949486
#
# Top N = 30
# Precision (how many songs liked by user in all recommended): 0.0006666666666666666
# Recall (how many songs collected by user been recommended): 0.001263823064770932
# F1-Score: 0.000872885979268958
#
# Top N = 20
# Precision (how many songs liked by user in all recommended): 0.00075
# Recall (how many songs collected by user been recommended): 0.0009478672985781991
# F1-Score: 0.000837404047452896

# %% [markdown]
# Here, we attempted to incorporate the local mean into the original content-based algorithm. This involved adding an adaptive recommendation threshold based on the similarity between a specific user profile and their training set data. If a user's preferences are more uniform, the local mean is higher; conversely, it is lower if the preferences are more diverse. Recommendations for the top N songs are made based on the distance between this local mean and songs not yet favorited by the user. The diagram above shows the performance of this model across different top N values. It is evident that the model performs best when recommending the top 100 songs, but its performance is not as good as the original content-based algorithm.

# %% [markdown]
# # User base recommendation (profile vs profile)

# %%
top_N = [100,50,30,20]
correct = [0,0,0,0]
total_rcmd = [0,0,0,0]
total_collect = [0,0,0,0]

# %%
all_profiles = tfidf.transform(grouped_df['text1'])
for id in tqdm(test_user_ids, desc="Processing users"):
    profile_index = grouped_df[grouped_df['user_id'] == id].index[0]
    profile = all_profiles[profile_index]
    other_users = grouped_df[~(grouped_df['user_id'] == id)].copy()
    other_profiles = all_profiles[[i for i in range(all_profiles.shape[0]) if i != profile_index]]
    similarity_score = cosine_similarity(other_profiles, profile).flatten()
    other_users['similarity'] = similarity_score
    other_users = other_users.sort_values(by='similarity', ascending=False)
    recommended_songs = pd.DataFrame()
    user_collect = train_df[train_df['user_id'] == id]
    user_test = test_df[test_df['user_id'] == id]
    added = [False,False,False,False]
    for oid in other_users['user_id'].unique():
        other_collect = train_df[train_df['user_id'] == oid].copy()
        user_notcollect = other_collect[~other_collect['text'].isin(user_collect['text'])]
        if len(recommended_songs) > 0:
            user_notcollect = user_notcollect[~user_notcollect['text'].isin(recommended_songs['text'])]
        recommended_songs = pd.concat([recommended_songs, user_notcollect])
        for n in range(len(top_N)):
            if len(recommended_songs) >= top_N[n] and not added[n] :
                recommended_songs = recommended_songs.head(top_N[n])
                recommended_songs['actual'] = recommended_songs.apply(
                    lambda row: 1 if row['text'] in user_test['text'].values else 0, axis=1
                )
                correct[n] += recommended_songs['actual'].sum()
                total_rcmd[n] += top_N[n]
                total_collect[n] += len(user_test)
                added[n] = True
                #print(f"User {id}, top_N {top_N[n]}: Correct = {correct[n]}, Total Rcmd = {total_rcmd[n]}, Total Collect = {total_collect[n]}")
                break
        finished = True
        for add in added:
            if not add:
                finished = False
        if finished:
            break
# Out:
# Processing users: 100%|██████████| 200/200 [01:31<00:00,  2.18it/s]

# %%
result_output(top_N,correct,total_rcmd,total_collect)
# Out:
# Top N = 100
# Precision (how many songs liked by user in all recommended): 0.0166
# Recall (how many songs collected by user been recommended): 0.10489731437598736
# F1-Score: 0.028663932657025683
#
# Top N = 50
# Precision (how many songs liked by user in all recommended): 0.0207
# Recall (how many songs collected by user been recommended): 0.06540284360189573
# F1-Score: 0.031447018609950625
#
# Top N = 30
# Precision (how many songs liked by user in all recommended): 0.023666666666666666
# Recall (how many songs collected by user been recommended): 0.04486571879936809
# F1-Score: 0.03098745226404801
#
# Top N = 20
# Precision (how many songs liked by user in all recommended): 0.025
# Recall (how many songs collected by user been recommended): 0.0315955766192733
# F1-Score: 0.027913468248429867

# %% [markdown]
# Here, we tried a recommendation algorithm that recommends songs to users based on the similarity of user profiles by comparing their similarities and selecting songs from the favorite lists of similar users. The algorithm ranks other users by their similarity and begins recommending songs favorited by the most similar user, continuing in this manner until the top N songs have been recommended. The diagram above shows the performance of this model with different top N settings. It can be seen that the algorithm performs best when recommending the top 50 songs, and its recommendation performance has improved compared to the previous content-based algorithm.

# %% [markdown]
# # Matrix decomposition

# %%
train_df['label'] = 1

# %%
import pandas as pd
import numpy as np
from surprise import Dataset, Reader, SVD, accuracy
from sklearn.metrics import f1_score, precision_score, recall_score
import random

user_ids = train_df['user_id'].unique()
song_ids = song_raw['song'].unique()

user_id_mapping = {id: i for i, id in enumerate(user_ids)}
song_id_mapping = {id: i for i, id in enumerate(song_ids)}

train_df['user_id_idx'] = train_df['user_id'].map(user_id_mapping)
train_df['song_id_idx'] = train_df['trackname'].map(song_id_mapping)

# %%
reader = Reader(rating_scale=(0, 1))
train_data = Dataset.load_from_df(train_df[['user_id_idx', 'song_id_idx', 'label']], reader)

trainset = train_data.build_full_trainset()

algo = SVD()
algo.fit(trainset)

# %%
top_N = [100,50,30,20]
correct = [0,0,0,0]
total_rcmd = [0,0,0,0]
total_collect = [0,0,0,0]
for id in tqdm(test_user_ids, desc="Processing users"):
    user_test = test_df[test_df['user_id'] == id]
    user_collect = train_df[train_df['user_id'] == id]
    user_notcollect = song_raw[~song_raw['text'].isin(user_collect['text'])].copy()
    user_notcollect['label'] = user_notcollect.apply(
        lambda row: 1 if row['text'] in user_test['text'].values else 0, axis=1
    )
    user_notcollect['user_id'] = id
    user_notcollect['user_id_idx'] = user_notcollect['user_id'].map(user_id_mapping)
    user_notcollect['song_id_idx'] = user_notcollect['song'].map(song_id_mapping)

    testset = list(zip(user_notcollect['user_id_idx'], user_notcollect['song_id_idx'], user_notcollect['label']))
    predictions = algo.test(testset)
    scores = [est for (_, _, _, est, _) in predictions]
    user_notcollect['score'] = scores
    recommended_songs = user_notcollect.sort_values(by='score', ascending=False)
    for n in range(len(top_N)):
        recommended_songs = recommended_songs.head(top_N[n])
        correct[n] += recommended_songs['label'].sum()
        total_rcmd[n] += top_N[n]
        total_collect[n] += len(user_test)
# Out:
# Processing users: 100%|██████████| 200/200 [03:53<00:00,  1.17s/it]

# %%
result_output(top_N,correct,total_rcmd,total_collect)
# Out:
# Top N = 100
# Precision (how many songs liked by user in all recommended): 0.00015
# Recall (how many songs collected by user been recommended): 0.0009478672985781991
# F1-Score: 0.00025901143967191884
#
# Top N = 50
# Precision (how many songs liked by user in all recommended): 0.0001
# Recall (how many songs collected by user been recommended): 0.000315955766192733
# F1-Score: 0.0001519179642992784
#
# Top N = 30
# Precision (how many songs liked by user in all recommended): 0.00016666666666666666
# Recall (how many songs collected by user been recommended): 0.000315955766192733
# F1-Score: 0.0002182214948172395
#
# Top N = 20
# Precision (how many songs liked by user in all recommended): 0.00025
# Recall (how many songs collected by user been recommended): 0.000315955766192733
# F1-Score: 0.0002791346824842987

# %%
from surprise import KNNBasic
algo = KNNBasic()
algo.fit(trainset)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
top_N = [100,50,30,20]
correct = [0,0,0,0]
total_rcmd = [0,0,0,0]
total_collect = [0,0,0,0]
for id in tqdm(test_user_ids, desc="Processing users"):
    user_test = test_df[test_df['user_id'] == id]
    user_collect = train_df[train_df['user_id'] == id]
    user_notcollect = song_raw[~song_raw['text'].isin(user_collect['text'])].copy()
    user_notcollect['label'] = user_notcollect.apply(
        lambda row: 1 if row['text'] in user_test['text'].values else 0, axis=1
    )
    user_notcollect['user_id'] = id
    user_notcollect['user_id_idx'] = user_notcollect['user_id'].map(user_id_mapping)
    user_notcollect['song_id_idx'] = user_notcollect['song'].map(song_id_mapping)

    testset = list(zip(user_notcollect['user_id_idx'], user_notcollect['song_id_idx'], user_notcollect['label']))
    predictions = algo.test(testset)
    scores = [est for (_, _, _, est, _) in predictions]
    user_notcollect['score'] = scores
    recommended_songs = user_notcollect.sort_values(by='score', ascending=False)
    for n in range(len(top_N)):
        recommended_songs = recommended_songs.head(top_N[n])
        correct[n] += recommended_songs['label'].sum()
        total_rcmd[n] += top_N[n]
        total_collect[n] += len(user_test)
# Out:
# Processing users: 100%|██████████| 200/200 [07:35<00:00,  2.28s/it]

# %%
result_output(top_N,correct,total_rcmd,total_collect)
# Out:
# Top N = 100
# Precision (how many songs liked by user in all recommended): 0.0002
# Recall (how many songs collected by user been recommended): 0.001263823064770932
# F1-Score: 0.00034534858622922514
#
# Top N = 50
# Precision (how many songs liked by user in all recommended): 0.0003
# Recall (how many songs collected by user been recommended): 0.0009478672985781991
# F1-Score: 0.0004557538928978352
#
# Top N = 30
# Precision (how many songs liked by user in all recommended): 0.0005
# Recall (how many songs collected by user been recommended): 0.0009478672985781991
# F1-Score: 0.0006546644844517185
#
# Top N = 20
# Precision (how many songs liked by user in all recommended): 0.00075
# Recall (how many songs collected by user been recommended): 0.0009478672985781991
# F1-Score: 0.000837404047452896

# %%
from surprise import BaselineOnly

bsl_options = {"method": "als", "n_epochs": 30, "reg_u": 12, "reg_i": 5}
algo = BaselineOnly(bsl_options=bsl_options)
algo.fit(trainset)
# Out:
# Estimating biases using als...

# %%
top_N = [100,50,30,20]
correct = [0,0,0,0]
total_rcmd = [0,0,0,0]
total_collect = [0,0,0,0]
for id in tqdm(test_user_ids, desc="Processing users"):
    user_test = test_df[test_df['user_id'] == id]
    user_collect = train_df[train_df['user_id'] == id]
    user_notcollect = song_raw[~song_raw['text'].isin(user_collect['text'])].copy()
    user_notcollect['label'] = user_notcollect.apply(
        lambda row: 1 if row['text'] in user_test['text'].values else 0, axis=1
    )
    user_notcollect['user_id'] = id
    user_notcollect['user_id_idx'] = user_notcollect['user_id'].map(user_id_mapping)
    user_notcollect['song_id_idx'] = user_notcollect['song'].map(song_id_mapping)

    testset = list(zip(user_notcollect['user_id_idx'], user_notcollect['song_id_idx'], user_notcollect['label']))
    predictions = algo.test(testset)
    scores = [est for (_, _, _, est, _) in predictions]
    user_notcollect['score'] = scores
    recommended_songs = user_notcollect.sort_values(by='score', ascending=False)
    for n in range(len(top_N)):
        recommended_songs = recommended_songs.head(top_N[n])
        correct[n] += recommended_songs['label'].sum()
        total_rcmd[n] += top_N[n]
        total_collect[n] += len(user_test)
# Out:
# Processing users: 100%|██████████| 200/200 [03:56<00:00,  1.18s/it]

# %%
result_output(top_N,correct,total_rcmd,total_collect)
# Out:
# Top N = 100
# Precision (how many songs liked by user in all recommended): 0.0002
# Recall (how many songs collected by user been recommended): 0.001263823064770932
# F1-Score: 0.00034534858622922514
#
# Top N = 50
# Precision (how many songs liked by user in all recommended): 0.0003
# Recall (how many songs collected by user been recommended): 0.0009478672985781991
# F1-Score: 0.0004557538928978352
#
# Top N = 30
# Precision (how many songs liked by user in all recommended): 0.0005
# Recall (how many songs collected by user been recommended): 0.0009478672985781991
# F1-Score: 0.0006546644844517185
#
# Top N = 20
# Precision (how many songs liked by user in all recommended): 0.00075
# Recall (how many songs collected by user been recommended): 0.0009478672985781991
# F1-Score: 0.000837404047452896

# %% [markdown]
# Here, we ignore the available content in the dataset and recommend songs to users solely based on user interaction feedback. We constructed a sparse matrix indicating whether a user has favorited a particular song (1 if favorited) and allowed three models to learn and predict the latent relationships between users and items. The models return a prediction value for the songs not favorited by the user, and then the top N songs are recommended based on this prediction value (the higher the value, the more likely it is to be favorited).
#
# We trained three models: SGD using matrix factorization, KNN, and a baseline model. The three diagrams above show the results of returning the top N predictions for each model. It can be seen that all three models perform best when returning the top 20 items. However, their performance is not as good as the previous user-based recommender. This may be because these models are not suitable for our task, as our dataset only contains songs favorited by users, meaning all the true labels are 1. This makes it a one-class classification task, and we do not have other samples to help the models fit properly. The models are more likely to learn to predict that all classes have a high likelihood of being favorited, leading to poor classification performance.
