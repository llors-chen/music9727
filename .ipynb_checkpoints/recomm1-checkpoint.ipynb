# %%
import pandas as pd

# %%
user_raw = pd.read_csv('../dataset/spotify_dataset.csv',on_bad_lines='skip')
song_raw = pd.read_csv('../dataset/spotify_millsongdata.csv')
user_raw.columns = user_raw.columns.str.replace('"', '').str.strip()
song_raw = song_raw.drop('link', axis=1)

# %%
song_raw
# Out:
#              artist                   song  \
# 0              ABBA  Ahe's My Kind Of Girl
# 1              ABBA       Andante, Andante
# 2              ABBA         As Good As New
# 3              ABBA                   Bang
# 4              ABBA       Bang-A-Boomerang
# ...             ...                    ...
# 57645  Ziggy Marley          Good Old Days
# 57646  Ziggy Marley          Hand To Mouth
# 57647          Zwan           Come With Me
# 57648          Zwan                 Desire
# 57649          Zwan              Heartsong
#
#                                                     text
# 0      Look at her face, it's a wonderful face  \r\nA...
# 1      Take it easy with me, please  \r\nTouch me gen...
# 2      I'll never know why I had to go  \r\nWhy I had...
# 3      Making somebody happy is a question of give an...
# 4      Making somebody happy is a question of give an...
# ...                                                  ...
# 57645  Irie days come on play  \r\nLet the angels fly...
# 57646  Power to the workers  \r\nMore power  \r\nPowe...
# 57647  all you need  \r\nis something i'll believe  \...
# 57648  northern star  \r\nam i frightened  \r\nwhere ...
# 57649  come in  \r\nmake yourself at home  \r\ni'm a ...
#
# [57650 rows x 3 columns]

# %%
user_raw
# Out:
#                                    user_id                        artistname  \
# 0         9cc0cfd4d7d7885102480dd99e7a90d6                    Elvis Costello
# 1         9cc0cfd4d7d7885102480dd99e7a90d6  Elvis Costello & The Attractions
# 2         9cc0cfd4d7d7885102480dd99e7a90d6                      Tiffany Page
# 3         9cc0cfd4d7d7885102480dd99e7a90d6  Elvis Costello & The Attractions
# 4         9cc0cfd4d7d7885102480dd99e7a90d6                    Elvis Costello
# ...                                    ...                               ...
# 12891675  2302bf9c64dc63d88a750215ed187f2c                       Mötley Crüe
# 12891676  2302bf9c64dc63d88a750215ed187f2c                       John Lennon
# 12891677  2302bf9c64dc63d88a750215ed187f2c                         Tom Petty
# 12891678  2302bf9c64dc63d88a750215ed187f2c                         Tom Petty
# 12891679  2302bf9c64dc63d88a750215ed187f2c                          Skid Row
#
#                                                   trackname    playlistname
# 0                      (The Angels Wanna Wear My) Red Shoes  HARD ROCK 2010
# 1         (What's So Funny 'Bout) Peace, Love And Unders...  HARD ROCK 2010
# 2                                          7 Years Too Late  HARD ROCK 2010
# 3                                     Accidents Will Happen  HARD ROCK 2010
# 4                                                    Alison  HARD ROCK 2010
# ...                                                     ...             ...
# 12891675                                          Wild Side          iPhone
# 12891676                                              Woman          iPhone
# 12891677                        You Don't Know How It Feels          iPhone
# 12891678                                       You Wreck Me          iPhone
# 12891679                                    Youth Gone Wild          iPhone
#
# [12891680 rows x 4 columns]

# %%
merged_df = pd.merge(user_raw, song_raw, how='left', left_on=['trackname', 'artistname'], right_on=['song', 'artist'])
merged_df = merged_df.dropna()
merged_df = merged_df.drop_duplicates()
merged_df.reset_index(drop=True, inplace=True)
merged_df.to_csv('../dataset/merge.csv', index=False)

# %%
merged_df = pd.read_csv('../dataset/merge.csv')
merged_df
# Out:
#                                  user_id           artistname  \
# 0       9cc0cfd4d7d7885102480dd99e7a90d6       Elvis Costello
# 1       9cc0cfd4d7d7885102480dd99e7a90d6       Paul McCartney
# 2       9cc0cfd4d7d7885102480dd99e7a90d6       Paul McCartney
# 3       9cc0cfd4d7d7885102480dd99e7a90d6        Crowded House
# 4       9cc0cfd4d7d7885102480dd99e7a90d6        Crowded House
# ...                                  ...                  ...
# 980823  2302bf9c64dc63d88a750215ed187f2c          Soundgarden
# 980824  2302bf9c64dc63d88a750215ed187f2c          Def Leppard
# 980825  2302bf9c64dc63d88a750215ed187f2c         Jimi Hendrix
# 980826  2302bf9c64dc63d88a750215ed187f2c            Metallica
# 980827  2302bf9c64dc63d88a750215ed187f2c  Stone Temple Pilots
#
#                            trackname    playlistname               artist  \
# 0                             Alison  HARD ROCK 2010       Elvis Costello
# 1                    Band On The Run  HARD ROCK 2010       Paul McCartney
# 2                      Dance Tonight  HARD ROCK 2010       Paul McCartney
# 3              Don't Dream It's Over  HARD ROCK 2010        Crowded House
# 4                  Fall At Your Feet  HARD ROCK 2010        Crowded House
# ...                              ...             ...                  ...
# 980823       The Day I Tried To Live          iPhone          Soundgarden
# 980824             Too Late For Love          iPhone          Def Leppard
# 980825  Voodoo Child (Slight Return)          iPhone         Jimi Hendrix
# 980826     Welcome Home (Sanitarium)          iPhone            Metallica
# 980827                 Wicked Garden          iPhone  Stone Temple Pilots
#
#                                 song  \
# 0                             Alison
# 1                    Band On The Run
# 2                      Dance Tonight
# 3              Don't Dream It's Over
# 4                  Fall At Your Feet
# ...                              ...
# 980823       The Day I Tried To Live
# 980824             Too Late For Love
# 980825  Voodoo Child (Slight Return)
# 980826     Welcome Home (Sanitarium)
# 980827                 Wicked Garden
#
#                                                      text
# 0       Oh it's so funny to be seeing you after so lon...
# 1       Stuck inside these four walls,  \r\nSent insid...
# 2       Everybody gonna dance tonight  \r\nEverybody g...
# 3       There is freedom within, there is freedom with...
# 4       I'm really close tonight  \r\nAnd I feel like ...
# ...                                                   ...
# 980823  I woke the same as any other day  \r\nExcept a...
# 980824  Somewhere in the distance I hear the bells rin...
# 980825  Well, I stand up next to a mountain  \r\nAnd I...
# 980826  Welcome to where time stands still  \r\nNo one...
# 980827  Can you see like a child?  \r\nCan you see wha...
#
# [980828 rows x 7 columns]

# %% [markdown]
# # Content Base recommend

# %%
train_list = []
test_list = []


for user_id, user_data in merged_df.groupby('user_id'):
    train_size = int(len(user_data) * 0.8)
    train_data = user_data.iloc[:train_size]
    test_data = user_data.iloc[train_size:]
    
    train_list.append(train_data)
    test_list.append(test_data)

train_df = pd.concat(train_list)
test_df = pd.concat(test_list)

# %%
train_df
# Out:
#                                  user_id         artistname         trackname  \
# 711787  00055176fea33f6e027cd3302289378b          Green Day           21 Guns
# 711788  00055176fea33f6e027cd3302289378b      One Direction        Act My Age
# 711789  00055176fea33f6e027cd3302289378b         Ed Sheeran  All Of The Stars
# 711790  00055176fea33f6e027cd3302289378b          Green Day    American Idiot
# 711791  00055176fea33f6e027cd3302289378b           Maroon 5           Animals
# ...                                  ...                ...               ...
# 194411  fff77dadf8528083c920b9c018847e8b        The Killers    Mr. Brightside
# 194412  fff77dadf8528083c920b9c018847e8b  Justin Timberlake           My Love
# 194413  fff77dadf8528083c920b9c018847e8b        The Killers      Read My Mind
# 194414  fff77dadf8528083c920b9c018847e8b       Lana Del Rey              Ride
# 194415  fff77dadf8528083c920b9c018847e8b        The Killers          Runaways
#
#             playlistname             artist              song  \
# 711787              favs          Green Day           21 Guns
# 711788              favs      One Direction        Act My Age
# 711789              favs         Ed Sheeran  All Of The Stars
# 711790              favs          Green Day    American Idiot
# 711791              favs           Maroon 5           Animals
# ...                  ...                ...               ...
# 194411  Liked from Radio        The Killers    Mr. Brightside
# 194412  Liked from Radio  Justin Timberlake           My Love
# 194413  Liked from Radio        The Killers      Read My Mind
# 194414  Liked from Radio       Lana Del Rey              Ride
# 194415  Liked from Radio        The Killers          Runaways
#
#                                                      text
# 711787  Do you know what's worth fighting for,  \r\nWh...
# 711788  [Verse 1: Niall]  \r\nWhen I'm fat and old  \r...
# 711789  It's just another night, and I'm staring at th...
# 711790  Don't want to be an American idiot.  \r\nDon't...
# 711791  [Chorus]  \r\nBaby I'm preying on you tonight,...
# ...                                                   ...
# 194411  Coming out of my cage  \r\nAnd I've been doing...
# 194412  If I wrote you a symphony  \r\nJust to say how...
# 194413  On the corner of main street  \r\nJust tryin' ...
# 194414  I've been out on that open road  \r\nYou can b...
# 194415  Blonde hair blowin' in the summer wind  \r\nA ...
#
# [778872 rows x 7 columns]

# %%
test_df
# Out:
#                                  user_id         artistname  \
# 711808  00055176fea33f6e027cd3302289378b         Little Mix
# 711809  00055176fea33f6e027cd3302289378b         Ed Sheeran
# 711810  00055176fea33f6e027cd3302289378b  Natalie Imbruglia
# 711811  00055176fea33f6e027cd3302289378b         Bruno Mars
# 711812  00055176fea33f6e027cd3302289378b      One Direction
# ...                                  ...                ...
# 194419  fff77dadf8528083c920b9c018847e8b       Fall Out Boy
# 194420  fff77dadf8528083c920b9c018847e8b       Fall Out Boy
# 194421  fff77dadf8528083c920b9c018847e8b        The Killers
# 194422  fff77dadf8528083c920b9c018847e8b       Fall Out Boy
# 194423  fff77dadf8528083c920b9c018847e8b           Coldplay
#
#                             trackname      playlistname             artist  \
# 711808       They Just Don't Know You              favs         Little Mix
# 711809              Thinking Out Loud              favs         Ed Sheeran
# 711810                           Torn              favs  Natalie Imbruglia
# 711811                       Treasure              favs         Bruno Mars
# 711812      Where Do Broken Hearts Go              favs      One Direction
# ...                               ...               ...                ...
# 194419  The (After) Life Of The Party  Liked from Radio       Fall Out Boy
# 194420                  Tiffany Blews  Liked from Radio       Fall Out Boy
# 194421                  Under The Gun  Liked from Radio        The Killers
# 194422           What A Catch, Donnie  Liked from Radio       Fall Out Boy
# 194423                        What If  Liked from Radio           Coldplay
#
#                                  song  \
# 711808       They Just Don't Know You
# 711809              Thinking Out Loud
# 711810                           Torn
# 711811                       Treasure
# 711812      Where Do Broken Hearts Go
# ...                               ...
# 194419  The (After) Life Of The Party
# 194420                  Tiffany Blews
# 194421                  Under The Gun
# 194422           What A Catch, Donnie
# 194423                        What If
#
#                                                      text
# 711808  (JADE)  \r\nDaddy doesn't think  \r\nThat you'...
# 711809  [Verse 1]  \r\nWhen your legs don't work like ...
# 711810  I thought I saw a man brought to life  \r\nHe ...
# 711811  Give me all, give me all, give me all your att...
# 711812  [Verse 1: Niall Horan]  \r\nCounted all my mis...
# ...                                                   ...
# 194419  I'm a stitch away from making it  \r\nAnd a sc...
# 194420  I'm not a cry baby  \r\nI'm the cry baby  \r\n...
# 194421  She's got her halo and wings  \r\nHidden under...
# 194422  I got troubled thoughts  \r\nAnd the self-este...
# 194423  What if there was no lie  \r\nNothing wrong, n...
#
# [201956 rows x 7 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
import re
import nltk
from nltk.corpus import stopwords, wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
nltk.download('stopwords')
nltk.download('punkt')

ps = PorterStemmer()
stop_words = set(stopwords.words('english'))
def preprocess_text(text):
    text = re.sub(r'\r\n', ' ', text)
    text = text.lower()
    text = re.sub(r'[^\w\s\'-]', '', text) 
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word not in stop_words]
    tokens = [ps.stem(word) for word in tokens]
    return ' '.join(tokens)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\11580\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\11580\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
song_raw['text1'] = song_raw['text'].apply(preprocess_text)

# %%
tfidf = TfidfVectorizer()
tfidf.fit_transform(song_raw['text1'])
# Out:
# <57650x65262 sparse matrix of type '<class 'numpy.float64'>'
# 	with 3468157 stored elements in Compressed Sparse Row format>

# %%
train_df['text1'] = train_df['text'].apply(preprocess_text)
train_df.to_csv('../dataset/train_df.csv', index=False)

# %%
train_df = pd.read_csv('../dataset/train_df.csv')

# %%
test_df['text1'] = test_df['text'].apply(preprocess_text)
test_df.to_csv('../dataset/test_df.csv', index=False)

# %%
test_df = pd.read_csv('../dataset/test_df.csv')

# %%
grouped_df = train_df.groupby('user_id').agg({
    'text1': ' '.join
}).reset_index()
grouped_df
# Out:
#                                 user_id  \
# 0      00055176fea33f6e027cd3302289378b
# 1      0007f3dd09c91198371454c608d47f22
# 2      000b0f32b5739f052b9d40fcc5c41079
# 3      000c11a16c89aa4b14b328080f5954ee
# 4      00123e0f544dee3ab006aa7f1e5725a7
# ...                                 ...
# 13014  ffe11226cdea81a2db9262c0ec7f5d71
# 13015  ffe32d5412269f3041c58cbf0dde3306
# 13016  fff60baf392613ed33f745b89a9b38f7
# 13017  fff616055993498d6127f3f467cf9f2b
# 13018  fff77dadf8528083c920b9c018847e8b
#
#                                                    text1
# 0      know 's worth fight 's worth die take breath a...
# 1      play hous put favorit record get get crystal m...
# 2      christma time happi cheer fun children call fa...
# 3      late 've 've lose sleep dream thing could babi...
# 4      love got lost said constant northern star said...
# ...                                                  ...
# 13014  gim fuel gim fire gim desir ooh turn oni see r...
# 13015  scrapbook 's fill pictur lead men well babi n'...
# 13016  're imposs scream moan chill soul n't want hea...
# 13017  moan though cri oh 's build shine take slow kn...
# 13018  dead dead 're live head sinc fell spell live w...
#
# [13019 rows x 2 columns]
